# %% [markdown]
# # Your new position as Data Scientist in logistics 📦
#
# ----
#
# _In this project you will solve an exemplary use case. Please note that all data is fictitious. This is not a project of the Austrian Post, it is rather representative for any job as a Data Scientist._
#
# Dear student,
#
# welcome to the Data Science project notebook 📊📝
#
# In the following notebook, we are going to look at various techniques we learned during the lecture. We apply our knowledge to help a logistics company better predict their parcel delivery times. The dataset was crafted by me -- it is likely that the numbers of a real logistics company differ a lot from the ones in the dataset.
#
# Please follow these rules:
#
# * Your submission should contain **only this notebook (.ipynb)**. **Zip the notebook file** into one archive and submit this archive until **15.12.2022, 13:15**.
#
# * The project is **meant to be solved alone**. This means, that you are **not allowed to share code or answers** with your colleagues. However, I am totally **fine with googling for solution approaches or chatting with your colleagues about a problem** (as long as you don't exchange any source code or answers with them).
#
# * I am 100% fine and happy if you deepen your understanding by using methods and code which we did not cover in the lecture - just make sure to **state your sources**!
#
# * For non-coding tasks I usually stated how many words should be used at maximum. Please **try to stay within that word limit**.
#
# * Sometimes markdown (text) cells are compiled, i.e. they are not in edit mode. Double click these cells so you can edit them. **You have to work (code or write a text) in each cell which contains a 🔨-symbol!**
#
# * If you are unsure about an answer or your solution does not fit the answer template, feel free to write your problems into the answer field. If you can describe why you struggle or why you cannot answer a question, I will pay regard to your remarks.
#
# * It is important that you put the code you used to answer a question into the notebook. If you only post a textual answer or code which does not allow to draw your conclusions, you cannot get full points for that task.
#
# * Feel free to add additional cells to this notebook (click the + button) if you need them.
#
# * At no point is it necessary to perform calculations by hand. Please use Python for working on the tasks.
#
# * As explained in the lecture, it is important to regularily save and download the current version of your notebook to not lose any progress you made!
#
# * If you have any questions: **Do not hesitate to contact me**. The earlier, the better :) $\rightarrow$ <a href="mailto:mail@mci-datascience.at">📬 mail@mci-datascience.at</a>
#
#
# Godspeed!
#
# Hilko
#
# ----
#
# <span style="display: none">Version: 0.0.1</span>
#
# ### Introduction 👋🏼
#
# Finally you made it! You are a Data Scientist and have landed a job as a Data Scientist at the Austrian Post in the logistics department!

# %% [markdown]
# <center> <img src="data:image/jpeg;base64,..."></center>

# %% [markdown]
# Right on your first day of work, you'll be asked, "What do you actually do as a Data Scientist?"
#
# **📝 Your assignment**: Explain your tasks using the OSEMN process. Go into each step of the process and explain what needs to be done in each step (max 100 words).

# %% [markdown]
# 🔨 Your answer here 🔨

# %% [markdown]
# To add value to the company, you ask your colleagues what problems there are in logistics. "Everything is actually going great, but we can't give customers a good estimate of how long it will take for a package to reach them," one colleague tells you.
#
# You want to solve the problem and approach your boss. He's thrilled that you want to take care of the problem and immediately gives you a record: "Here's an excerpt from our shipping system.... It's best to get an overview first."
#
# You get the file `past_parcels.csv`. The data is stored in the data directory.
#
# **📝 Your assignment**: Load the file `past_parcels.csv` into a Pandas dataset assign it to the variable `past_parcels_df`.

# %%
import pandas as pd

# %%
### 🔨 Your code here 🔨 ###

# %% [markdown]
# The columns of the dataframe have the following meaning:
# <table style="border-collapse:collapse;border-spacing:0" class="tg"><thead><tr><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal"><span style="font-weight:bold">Column</span></th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal"><span style="font-weight:bold">Meaning</span></th></tr></thead><tbody><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">id</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Random ID to track the parcel.</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">has_customs_clearance</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">If the parcel has customs clearance</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">is_correctly_labeled</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">If the parcel was correctly labeled by the sender</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">is_business_parcel</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">If the parcel was sent by a business (TRUE) or by a private person (FALSE)</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">is_sufficiently_packed</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">If the parcel was sufficiently packed</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">time_of_the_year</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">If the parcel was sent at a specific time of the year. Either None, HOLIDAY_BREAK or CHRISTIMAS.</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">sender_postal_zone</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Postal zone of the sender</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">receiver_postal_zone</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Postal zone of the parcel receiver</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">expected_delivery_days</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Prediction of the logistics company how long the parcel delivery would take. Your task will be to improve this prediction.</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">actual_delivery_days</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">How long the parcel delivery actually took.</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">chosen_delivery_type</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">The delivery type bought by the sender. Either STANDARD, NEXT_DAY, PRIORITY or SAME_DAY.</td></tr></tbody></table>

# %% [markdown]
# ### Data Scrubbing 🧽 and Data Exploration 🔍
#
# Your boss wants to have a first overview of the numbers, especially what the **min, max and average** of **expected and actual delivery days** are.
#
# **📝 Your assignment**:
# 1. Calculate the desired statistics using Python. (No need to write a text about it!) Remember how we calculated the basic statistics of a dataframe in the lecture.
# 2. Look at the actual delivery days: What strikes you about its min, max and/or average value (max 100 words)?

# %%
### 🔨 Your code for task 1 here 🔨 ###

# %% [markdown]
# ### 🔨 Your answer for task 2 here 🔨 ###

# %% [markdown]
# Your boss also notices that for some data points the actual_delivery_day is -1 and asks you what the reason could be.
#
# **📝 Your assignment**:
# 1. Display the entries of the DataFrame, where actual_delivery_day is -1.
# 2. Try to find out what the data points have in common when actual_delivery_day is -1 (max 100 words).

# %%
### 🔨 Your code for task 1 here 🔨 ###

# %% [markdown]
# ### 🔨 Your answer for task 2 here 🔨 ###

# %% [markdown]
# In the first step you want to find out how strong the correlation is between the expected delivery days and the actual delivery days.
#
# **📝 Your assignment**:
# 1. Calculate the correlation between `expected_delivery_days` and `actual_delivery_days`.
# 2. Describe in a text what the correlation means in this case (max 100 words).
#
# **💡 Hint**: If you need help to calculate the correlation, have a look on the Instagram Influencer exercise we did in the lecture!

# %%
### 🔨 Your code for task 1 here 🔨 ###

# %% [markdown]
# ### 🔨 Your answer for task 2 here 🔨 ###

# %% [markdown]
# ### Let's visualize the dataset 📊
#
# Your boss comes to you and says, "Hey, I'm really having trouble looking at these endless data tables. How am I supposed to learn anything from that?" You remember that visualizations help you to understand the data and you start visualizing the data set.
#
# **📝 Your assignment**:
#
# Create at least **two** different, meaningful visualizations. Use at least two different types of visualizations (e.g. a piechart and a boxplot).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
### 🔨 Your code for the first visualization here 🔨 ###

# %%
### 🔨 Your code for the second visualization here 🔨 ###

# %% [markdown]
# ### Data Modelling

# %% [markdown]
# ⚠️ This section is split up into three different subsections. If you fail to do one subsection, you **can continue with the next subsection**. This means, that if you fail to do the preprocessing or the data split up, you can still do the machine learning part! ⚠️
#
# *Data Preprocessing Part*
# 1. Drop the `id` and the `expected_delivery_days` columns from the `past_parcels_df` and save the result as `df_without_id`. Hint: Look at the <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html">drop</a> function from pandas.
# 2. Add a new column `same_postal_zone` to `df_without_id`. The column should have the following value: `(df_without_id['sender_postal_zone'] == df_without_id['receiver_postal_zone'])` (This means the column has the value TRUE if the sender's postal zone is the same as the receiver's postal zone).
# 3. Drop the columns `sender_postal_zone` and `receiver_postal_zone` in the `df_without_id` DataFrame. (Look again how you dropped the columns in task 1!)
# 4. Replace YES with `1` and NO with `0` in the columns `has_customs_clearance`, `is_correctly_labeled`, `is_business_parcel` and `is_sufficiently_packed`. Hint: Look at the <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html">replace</a> function from pandas.
# 5. Apply OneHotEncoding to the columns `time_of_the_year` and `chosen_delivery_type` and concat the result to the `df_without_id`. If the columns `time_of_the_year` and `chosen_delivery_type` exist in your `df_without_it`, delete the columns `time_of_the_year` and `chosen_delivery_type`.
#
# *Data Splitup*
# 1. Create a variable `df_target` which contains only the column `actual_delivery_days` from `df_without_id`
# 2. Create a variable `df_features` which contains every column from `df_without_id` except `actual_delivery_days` from `df_without_id`
# 3. Create the variables `x_train`, `x_test`, `y_train` and `y_test` with the function `train_test_split` and a **test_size of 0.2**.
#
# Hint: https://www.aboutdatablog.com/post/splitting-your-data-to-fit-any-machine-learning-model
#
# *Machine Learning Part*
#
# Create **two** different, regression machine learning models for predicting the actual_delivery_days (df_target) with the help of the features in your `df_features` DataFrame. **Remember, that for some machine learning algorithms, you need to do some preprocessing first**. Please save the first regression model in the variable `reg1`, the second in the variable `reg2`, ... Test your model on the test data by printing the score on the test data!
#
# **⚠️ Important**: Don't expect very high scores from your machine learning algorithms. Everything about 30 - 50% is totally fine, since the dataset does not contain enough information to reach very high scores. However, if you reach high scores - even better! The grading will focus on your code and methodology, not on the final accuracy!

# %%
##### Data Preprocessing Part #####
### 🔨 Your code for the data preprocessing part here 🔨 ###

# 1. 🔨 Drop columns

# 2. 🔨 Add feature same_postal_zone. You only need to replace the ... in the next line!
... = (df_without_id['sender_postal_zone'] == df_without_id['receiver_postal_zone'])

# 3. 🔨 Drop columns

# 4. 🔨 Replace Yes with 1 and No with 0

# 5. 🔨 OneHotEncoding time_of_year + chosen_delivery_type

# %%
# CHECKPOINT: The preprocessed data will be loaded into the variable df_without_id in the next step
# Please always execute this cell, even if you were able to do the preprocessing part!
df_without_id = pd.read_pickle('internal/data_preprocessing.pkl')

# %%
###### Data Splitup #####
### 🔨 Your code for the data splitup part here 🔨 ###

# %%
# CHECKPOINT: The data will be loaded into the variables X_train, X_test, y_train and y_test in the next step
# Please always execute this cell, even if you were able to do the previous part!
x_train, x_test, y_train, y_test =  pd.read_pickle('internal/X_train.pkl'), \
                                    pd.read_pickle('internal/X_test.pkl'), \
                                    pd.read_pickle('internal/y_train.pkl'), \
                                    pd.read_pickle('internal/y_test.pkl')

# %%
###### Machine Learning Part ######
### 🔨 Your code for the machine learning part here 🔨 ###

# %% [markdown]
# ### Ethics
#
# Your boss approaches you and suggests to use more features like the gender, nationality or religion of the package deliverer and the recipient for the machine learning model. What dangers do you see? Why could this be a bad idea? (max 300 words)

# %% [markdown]
# ### 🔨 Your answer here 🔨 ###

# %% [markdown]
# ### Done 🏁
# Good job 🥳. You give the boss your final model. Although the model does not work perfectly -- its predictions are definitely better than the ones by the previous algorithm.
#
# ---
#
# You are done doing the small Data Science Project. Please remember to **save this file**. Then **zip this notebook**. You can then **upload the archive to Sakai**, not later than 15.12.2022, 13:15.
